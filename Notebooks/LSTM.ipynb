# %% [markdown]
# ## Acceso a drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Bibliotecas necesarias

# %%
# !pip3 install pickle5
# Out:
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.11)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adadelta
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
from gensim.models import KeyedVectors
import tensorflow.keras.backend as K
import numpy as np
import io
import datetime
import pickle5 as pickle
from sklearn.metrics import classification_report

# %% [markdown]
# ## Definición del modelo

# %%
class LSTM:
  def __init__(self, input_dim, embedding_matrix, input_length=300):
    output_dim = 300
    input = Input(shape=(input_length,), name='input_1')
    embeddings = layers.Embedding(input_dim+1,output_dim,input_length=input_length, weights=[embedding_matrix], trainable=False)
    lstm = layers.LSTM(100, name='lstm_layer')

    embedding_output = embeddings(input)

    embedding_output = layers.SpatialDropout1D(0.2)(embedding_output)

    lstm_output = lstm(embedding_output)
    
    predictions = layers.Dense(23, activation='softmax', name='dense_layer')(lstm_output)
    self.model = Model([input],predictions)
    self.__compile()
    plot_model(self.model, to_file='/content/drive/My Drive/dicode/Backtranslation/lstm_model.png', show_shapes=True, show_dtype=True)
    print(self.model.summary())
  
  def __compile(self):
      self.model.compile(loss = tf.keras.losses.CategoricalCrossentropy() , optimizer='adam', metrics=['accuracy'])
    
  def fit(self, input, targets, epochs=5, batch_size=128):
      early_stopping_monitor = EarlyStopping(monitor = 'val_loss',patience = 20, min_delta=0.00001)
      callbacks = [early_stopping_monitor]
      history = self.model.fit([input], targets, epochs = epochs, batch_size = batch_size, callbacks = callbacks)
    
  def predict(self, input):
      return self.model.predict([input])
        
  def evaluate(self, input, targets, batch_size=128):
      return self.model.evaluate([input], targets, batch_size=batch_size)

# %% [markdown]
# ## Entrenamiento y evaluación

# %%
def load_data(path):
  data = np.load(path)
  return data['arr_0']

# %%
for fold in range(1,6):
  x_train = load_data('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/x_train.npz'.format(fold))
  y_train = load_data('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/y_train.npz'.format(fold))
  x_test = load_data('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/x_test.npz'.format(fold))
  y_test = load_data('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/y_test.npz'.format(fold))
  embedding_matrix = load_data('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/embedding_matrix.npz'.format(fold))
  with open('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/tokenizer.pickle'.format(fold), 'rb') as handle:
    tokenizer = pickle.load(handle)
  input_dim = len(tokenizer.word_index)
  lstm_model = LSTM(input_dim=input_dim, embedding_matrix=embedding_matrix)
  lstm_model.fit(x_train, y_train, epochs=10)
  lstm_model.evaluate(x_test, y_test)
  y_pred = lstm_model.predict(x_test)
  y_predicted = np.argmax(y_pred, axis=-1)
  y_true = np.argmax(y_test, axis=-1)
  report = classification_report(y_true, y_predicted)
  print(report)
  output_file = open('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/classification_report_lstm.txt'.format(fold), 'w',encoding='utf8')
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# embedding (Embedding)        (None, 300, 300)          44141400
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 300, 300)          0
# _________________________________________________________________
# lstm_layer (LSTM)            (None, 100)               160400
# _________________________________________________________________
# dense_layer (Dense)          (None, 23)                2323
# =================================================================
# Total params: 44,304,123
# Trainable params: 162,723
# Non-trainable params: 44,141,400
# _________________________________________________________________
# None
# Epoch 1/10
# 737/737 [==============================] - 55s 34ms/step - loss: 2.4602 - accuracy: 0.2604
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/10
# 737/737 [==============================] - 25s 34ms/step - loss: 1.4950 - accuracy: 0.5555
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/10
# 737/737 [==============================] - 25s 34ms/step - loss: 1.1229 - accuracy: 0.6677
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/10
# 737/737 [==============================] - 25s 34ms/step - loss: 0.9773 - accuracy: 0.7064
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/10
# 737/737 [==============================] - 25s 34ms/step - loss: 0.8844 - accuracy: 0.7326
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 6/10
# 737/737 [==============================] - 25s 34ms/step - loss: 0.8081 - accuracy: 0.7536
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 7/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.7545 - accuracy: 0.7675
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 8/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.7030 - accuracy: 0.7836
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 9/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.6615 - accuracy: 0.7955
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 10/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.6306 - accuracy: 0.8034
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 185/185 [==============================] - 4s 20ms/step - loss: 1.6668 - accuracy: 0.6571
#               precision    recall  f1-score   support
#
#            0       0.50      0.76      0.61      1806
#            1       0.68      0.75      0.71      1776
#            2       0.98      0.59      0.74       560
#            3       0.94      0.54      0.69      1029
#            4       0.90      0.69      0.78      1560
#            5       0.91      0.61      0.73      1644
#            6       0.84      0.67      0.75      1728
#            7       0.37      0.17      0.23       275
#            8       0.56      0.65      0.60       272
#            9       0.89      0.54      0.68       676
#           10       0.94      0.56      0.70      2187
#           11       0.91      0.68      0.78      1641
#           12       0.47      0.67      0.55       464
#           13       0.34      0.57      0.43       349
#           14       0.93      0.59      0.72       113
#           15       0.25      0.48      0.33       819
#           16       0.22      0.36      0.27       235
#           17       0.47      0.69      0.56       486
#           18       0.63      0.57      0.60       329
#           19       0.54      0.48      0.51       256
#           20       0.94      0.57      0.71      1445
#           21       0.65      0.77      0.71      1190
#           22       0.57      0.84      0.67      2744
#
#     accuracy                           0.66     23584
#    macro avg       0.67      0.60      0.61     23584
# weighted avg       0.73      0.66      0.67     23584
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 300, 300)          43616100
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 300, 300)          0
# _________________________________________________________________
# lstm_layer (LSTM)            (None, 100)               160400
# _________________________________________________________________
# dense_layer (Dense)          (None, 23)                2323
# =================================================================
# Total params: 43,778,823
# Trainable params: 162,723
# Non-trainable params: 43,616,100
# _________________________________________________________________
# None
# Epoch 1/10
# 737/737 [==============================] - 28s 35ms/step - loss: 2.4801 - accuracy: 0.2643
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/10
# 737/737 [==============================] - 26s 35ms/step - loss: 1.5005 - accuracy: 0.5672
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/10
# 737/737 [==============================] - 26s 35ms/step - loss: 1.1894 - accuracy: 0.6557
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/10
# 737/737 [==============================] - 26s 35ms/step - loss: 1.0375 - accuracy: 0.6957
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.9523 - accuracy: 0.7201
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 6/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.8794 - accuracy: 0.7406
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 7/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.8271 - accuracy: 0.7541
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 8/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.7714 - accuracy: 0.7696
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 9/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.7306 - accuracy: 0.7802
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 10/10
# 737/737 [==============================] - 25s 35ms/step - loss: 0.6975 - accuracy: 0.7875
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 185/185 [==============================] - 4s 20ms/step - loss: 0.6888 - accuracy: 0.7956
#               precision    recall  f1-score   support
#
#            0       0.73      0.74      0.74      1805
#            1       0.70      0.75      0.72      1775
#            2       0.85      0.90      0.87       559
#            3       0.89      0.86      0.87      1030
#            4       0.89      0.89      0.89      1560
#            5       0.89      0.83      0.86      1644
#            6       0.81      0.94      0.87      1728
#            7       0.57      0.23      0.33       274
#            8       0.72      0.58      0.64       273
#            9       0.80      0.90      0.85       677
#           10       0.88      0.88      0.88      2186
#           11       0.93      0.93      0.93      1642
#           12       0.66      0.57      0.61       465
#           13       0.73      0.52      0.60       349
#           14       0.93      0.88      0.90       113
#           15       0.52      0.45      0.48       818
#           16       0.50      0.38      0.43       235
#           17       0.73      0.62      0.67       486
#           18       0.78      0.66      0.71       329
#           19       0.76      0.50      0.60       256
#           20       0.81      0.97      0.88      1445
#           21       0.87      0.74      0.80      1191
#           22       0.72      0.77      0.74      2744
#
#     accuracy                           0.80     23584
#    macro avg       0.77      0.72      0.73     23584
# weighted avg       0.79      0.80      0.79     23584
#
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 300, 300)          43855200
# _________________________________________________________________
# spatial_dropout1d_2 (Spatial (None, 300, 300)          0
# _________________________________________________________________
# lstm_layer (LSTM)            (None, 100)               160400
# _________________________________________________________________
# dense_layer (Dense)          (None, 23)                2323
# =================================================================
# Total params: 44,017,923
# Trainable params: 162,723
# Non-trainable params: 43,855,200
# _________________________________________________________________
# None
# Epoch 1/10
# 737/737 [==============================] - 28s 36ms/step - loss: 2.4720 - accuracy: 0.2584
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/10
# 737/737 [==============================] - 27s 36ms/step - loss: 1.4687 - accuracy: 0.5765
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/10
# 737/737 [==============================] - 26s 36ms/step - loss: 1.1765 - accuracy: 0.6608
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/10
# 737/737 [==============================] - 26s 36ms/step - loss: 1.0393 - accuracy: 0.6965
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/10
# 737/737 [==============================] - 26s 36ms/step - loss: 0.9484 - accuracy: 0.7223
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 6/10
# 737/737 [==============================] - 26s 36ms/step - loss: 0.8805 - accuracy: 0.7400
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 7/10
# 737/737 [==============================] - 26s 36ms/step - loss: 0.8275 - accuracy: 0.7536
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 8/10
# 737/737 [==============================] - 26s 36ms/step - loss: 0.7763 - accuracy: 0.7659
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 9/10
# 737/737 [==============================] - 26s 36ms/step - loss: 0.7404 - accuracy: 0.7775
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 10/10
# 737/737 [==============================] - 26s 36ms/step - loss: 0.6972 - accuracy: 0.7895
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 185/185 [==============================] - 4s 21ms/step - loss: 0.6703 - accuracy: 0.7931
#               precision    recall  f1-score   support
#
#            0       0.72      0.74      0.73      1805
#            1       0.66      0.79      0.72      1775
#            2       0.90      0.89      0.90       559
#            3       0.73      0.92      0.82      1030
#            4       0.93      0.88      0.90      1560
#            5       0.76      0.94      0.84      1644
#            6       0.90      0.79      0.85      1728
#            7       0.70      0.39      0.50       274
#            8       0.67      0.65      0.66       273
#            9       0.82      0.83      0.82       677
#           10       0.88      0.87      0.87      2186
#           11       0.94      0.91      0.93      1642
#           12       0.68      0.62      0.65       464
#           13       0.69      0.60      0.64       350
#           14       0.83      0.88      0.85       112
#           15       0.55      0.50      0.52       819
#           16       0.79      0.31      0.45       235
#           17       0.71      0.64      0.68       486
#           18       0.75      0.70      0.72       328
#           19       0.70      0.56      0.62       256
#           20       0.83      0.92      0.87      1445
#           21       0.83      0.79      0.81      1190
#           22       0.78      0.71      0.75      2745
#
#     accuracy                           0.79     23583
#    macro avg       0.77      0.73      0.74     23583
# weighted avg       0.80      0.79      0.79     23583
#
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 300, 300)          43354500
# _________________________________________________________________
# spatial_dropout1d_3 (Spatial (None, 300, 300)          0
# _________________________________________________________________
# lstm_layer (LSTM)            (None, 100)               160400
# _________________________________________________________________
# dense_layer (Dense)          (None, 23)                2323
# =================================================================
# Total params: 43,517,223
# Trainable params: 162,723
# Non-trainable params: 43,354,500
# _________________________________________________________________
# None
# Epoch 1/10
# 737/737 [==============================] - 27s 35ms/step - loss: 2.5992 - accuracy: 0.2228
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/10
# 737/737 [==============================] - 26s 35ms/step - loss: 1.5253 - accuracy: 0.5598
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/10
# 737/737 [==============================] - 26s 35ms/step - loss: 1.2088 - accuracy: 0.6538
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/10
# 737/737 [==============================] - 26s 35ms/step - loss: 1.0705 - accuracy: 0.6900
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.9797 - accuracy: 0.7124
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 6/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.9101 - accuracy: 0.7309
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 7/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.8600 - accuracy: 0.7446
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 8/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.8051 - accuracy: 0.7604
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 9/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.7629 - accuracy: 0.7721
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 10/10
# 737/737 [==============================] - 26s 35ms/step - loss: 0.7260 - accuracy: 0.7802
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 185/185 [==============================] - 4s 20ms/step - loss: 0.6856 - accuracy: 0.7910
#               precision    recall  f1-score   support
#
#            0       0.68      0.73      0.70      1806
#            1       0.77      0.72      0.74      1775
#            2       0.84      0.91      0.87       559
#            3       0.85      0.87      0.86      1030
#            4       0.89      0.89      0.89      1560
#            5       0.76      0.95      0.85      1644
#            6       0.91      0.80      0.85      1728
#            7       0.66      0.36      0.47       275
#            8       0.69      0.62      0.66       273
#            9       0.78      0.87      0.82       677
#           10       0.84      0.87      0.86      2186
#           11       0.95      0.91      0.93      1642
#           12       0.66      0.52      0.58       464
#           13       0.78      0.55      0.65       349
#           14       0.90      0.75      0.82       113
#           15       0.49      0.40      0.44       819
#           16       0.48      0.36      0.41       234
#           17       0.71      0.72      0.72       485
#           18       0.78      0.60      0.68       329
#           19       0.69      0.64      0.66       256
#           20       0.91      0.88      0.89      1445
#           21       0.85      0.80      0.82      1190
#           22       0.71      0.80      0.75      2744
#
#     accuracy                           0.79     23583
#    macro avg       0.76      0.72      0.74     23583
# weighted avg       0.79      0.79      0.79     23583
#
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 300, 300)          42951900
# _________________________________________________________________
# spatial_dropout1d_4 (Spatial (None, 300, 300)          0
# _________________________________________________________________
# lstm_layer (LSTM)            (None, 100)               160400
# _________________________________________________________________
# dense_layer (Dense)          (None, 23)                2323
# =================================================================
# Total params: 43,114,623
# Trainable params: 162,723
# Non-trainable params: 42,951,900
# _________________________________________________________________
# None
# Epoch 1/10
# 737/737 [==============================] - 28s 36ms/step - loss: 2.4830 - accuracy: 0.2581
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/10
# 737/737 [==============================] - 27s 36ms/step - loss: 1.5194 - accuracy: 0.5629
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/10
# 737/737 [==============================] - 27s 36ms/step - loss: 1.1977 - accuracy: 0.6527
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/10
# 737/737 [==============================] - 26s 36ms/step - loss: 1.0569 - accuracy: 0.6923
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/10
# 737/737 [==============================] - 27s 36ms/step - loss: 0.9874 - accuracy: 0.7109
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 6/10
# 737/737 [==============================] - 26s 36ms/step - loss: 0.8983 - accuracy: 0.7306
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 7/10
# 737/737 [==============================] - 26s 36ms/step - loss: 0.8419 - accuracy: 0.7467
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 8/10
# 737/737 [==============================] - 26s 36ms/step - loss: 0.7863 - accuracy: 0.7650
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 9/10
# 737/737 [==============================] - 26s 36ms/step - loss: 0.7406 - accuracy: 0.7769
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 10/10
# 737/737 [==============================] - 27s 36ms/step - loss: 0.7094 - accuracy: 0.7853
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 185/185 [==============================] - 4s 21ms/step - loss: 0.7838 - accuracy: 0.7561
#               precision    recall  f1-score   support
#
#            0       0.75      0.70      0.73      1806
#            1       0.71      0.74      0.72      1775
#            2       0.86      0.90      0.88       559
#            3       0.87      0.85      0.86      1029
#            4       0.91      0.86      0.89      1560
#            5       0.94      0.81      0.87      1644
#            6       0.56      0.95      0.70      1728
#            7       0.53      0.43      0.47       275
#            8       0.71      0.58      0.64       272
#            9       0.82      0.85      0.83       677
#           10       0.72      0.53      0.61      2187
#           11       0.92      0.92      0.92      1641
#           12       0.69      0.62      0.66       464
#           13       0.67      0.54      0.60       349
#           14       0.89      0.77      0.82       113
#           15       0.57      0.46      0.51       819
#           16       0.56      0.37      0.45       235
#           17       0.71      0.70      0.70       486
#           18       0.77      0.50      0.60       329
#           19       0.69      0.56      0.62       257
#           20       0.82      0.96      0.88      1444
#           21       0.84      0.76      0.80      1190
#           22       0.70      0.75      0.73      2744
#
#     accuracy                           0.76     23583
#    macro avg       0.75      0.70      0.72     23583
# weighted avg       0.76      0.76      0.75     23583
