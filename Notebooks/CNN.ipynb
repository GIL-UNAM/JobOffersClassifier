# %% [markdown]
# ## Acceso a drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Bibliotecas necesarias

# %%
# !pip3 install pickle5
# Out:
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.11)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adadelta
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
from gensim.models import KeyedVectors
import tensorflow.keras.backend as K
import numpy as np
import io
import datetime
import pickle5 as pickle
from sklearn.metrics import classification_report

# %% [markdown]
# ## Definición del modelo

# %%
class CNN:
  def __init__(self, input_dim, embedding_matrix, input_length=300):
    output_dim = 300
    input = Input(shape=(input_length,), name='input_1')
    embeddings = layers.Embedding(input_dim+1,output_dim,input_length=input_length, weights=[embedding_matrix], trainable=False)
    conv1D = layers.Conv1D(128, 5, activation='relu', name='Conv1D_layer')

    embedding_output = embeddings(input)
    conv1D_output = conv1D(embedding_output)

    conv1D_output = layers.GlobalMaxPooling1D()(conv1D_output)
    
    predictions = layers.Dense(23, activation='softmax', name='dense_layer')(conv1D_output)
    self.model = Model([input],predictions)
    self.__compile()
    plot_model(self.model, to_file='/content/drive/My Drive/dicode/Backtranslation/cnn_model.png', show_shapes=True, show_dtype=True)
    print(self.model.summary())
  
  def __compile(self):
      self.model.compile(loss = tf.keras.losses.CategoricalCrossentropy() , optimizer='adam', metrics=['accuracy'])
    
  def fit(self, input, targets, epochs=5, batch_size=128):
      early_stopping_monitor = EarlyStopping(monitor = 'val_loss',patience = 20, min_delta=0.00001)
      callbacks = [early_stopping_monitor]
      history = self.model.fit([input], targets, epochs = epochs, batch_size = batch_size, callbacks = callbacks)
    
  def predict(self, input):
      return self.model.predict([input])
        
  def evaluate(self, input, targets, batch_size=128):
      return self.model.evaluate([input], targets, batch_size=batch_size)

# %% [markdown]
# ## Entrenamiento y evaluación

# %%
def load_data(path):
  data = np.load(path)
  return data['arr_0']

# %%
for fold in range(1,6):
  x_train = load_data('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/x_train.npz'.format(fold))
  y_train = load_data('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/y_train.npz'.format(fold))
  x_test = load_data('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/x_test.npz'.format(fold))
  y_test = load_data('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/y_test.npz'.format(fold))
  embedding_matrix = load_data('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/embedding_matrix.npz'.format(fold))
  with open('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/tokenizer.pickle'.format(fold), 'rb') as handle:
    tokenizer = pickle.load(handle)
  input_dim = len(tokenizer.word_index)
  cnn_model = CNN(input_dim=input_dim, embedding_matrix=embedding_matrix)
  cnn_model.fit(x_train, y_train, epochs=10)
  cnn_model.evaluate(x_test, y_test)
  y_pred = cnn_model.predict(x_test)
  y_predicted = np.argmax(y_pred, axis=-1)
  y_true = np.argmax(y_test, axis=-1)
  report = classification_report(y_true, y_predicted)
  print(report)
  output_file = open('/content/drive/My Drive/dicode/Backtranslation/K-Folds/{}-fold/classification_report_cnn.txt'.format(fold), 'w',encoding='utf8')
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# embedding (Embedding)        (None, 300, 300)          44141400
# _________________________________________________________________
# Conv1D_layer (Conv1D)        (None, 296, 128)          192128
# _________________________________________________________________
# global_max_pooling1d (Global (None, 128)               0
# _________________________________________________________________
# dense_layer (Dense)          (None, 23)                2967
# =================================================================
# Total params: 44,336,495
# Trainable params: 195,095
# Non-trainable params: 44,141,400
# _________________________________________________________________
# None
# Epoch 1/10
# 737/737 [==============================] - 35s 45ms/step - loss: 1.7812 - accuracy: 0.5202
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.8752 - accuracy: 0.7535
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.6766 - accuracy: 0.8050
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.5612 - accuracy: 0.8384
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.4654 - accuracy: 0.8653
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 6/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.3993 - accuracy: 0.8854
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 7/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.3476 - accuracy: 0.8986
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 8/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.3031 - accuracy: 0.9117
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 9/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.2718 - accuracy: 0.9211
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 10/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.2422 - accuracy: 0.9286
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 185/185 [==============================] - 5s 26ms/step - loss: 1.9144 - accuracy: 0.6655
#               precision    recall  f1-score   support
#
#            0       0.55      0.73      0.63      1806
#            1       0.64      0.75      0.69      1776
#            2       0.93      0.66      0.77       560
#            3       0.89      0.57      0.69      1029
#            4       0.92      0.69      0.79      1560
#            5       0.92      0.64      0.76      1644
#            6       0.83      0.74      0.79      1728
#            7       0.31      0.49      0.38       275
#            8       0.61      0.53      0.56       272
#            9       0.87      0.56      0.68       676
#           10       0.93      0.53      0.68      2187
#           11       0.95      0.70      0.81      1641
#           12       0.50      0.63      0.56       464
#           13       0.35      0.60      0.44       349
#           14       0.79      0.63      0.70       113
#           15       0.31      0.46      0.37       819
#           16       0.26      0.46      0.33       235
#           17       0.42      0.72      0.53       486
#           18       0.57      0.66      0.61       329
#           19       0.43      0.56      0.49       256
#           20       0.93      0.59      0.72      1445
#           21       0.58      0.78      0.67      1190
#           22       0.59      0.78      0.67      2744
#
#     accuracy                           0.67     23584
#    macro avg       0.66      0.63      0.62     23584
# weighted avg       0.73      0.67      0.68     23584
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 300, 300)          43616100
# _________________________________________________________________
# Conv1D_layer (Conv1D)        (None, 296, 128)          192128
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dense_layer (Dense)          (None, 23)                2967
# =================================================================
# Total params: 43,811,195
# Trainable params: 195,095
# Non-trainable params: 43,616,100
# _________________________________________________________________
# None
# Epoch 1/10
# 737/737 [==============================] - 34s 45ms/step - loss: 1.7884 - accuracy: 0.5230
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.9383 - accuracy: 0.7404
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.7452 - accuracy: 0.7894
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.6103 - accuracy: 0.8264
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.5207 - accuracy: 0.8522
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 6/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.4514 - accuracy: 0.8722
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 7/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.3970 - accuracy: 0.8861
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 8/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.3486 - accuracy: 0.8980
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 9/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.3179 - accuracy: 0.9078
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 10/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.2817 - accuracy: 0.9179
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 185/185 [==============================] - 5s 27ms/step - loss: 0.8346 - accuracy: 0.7711
#               precision    recall  f1-score   support
#
#            0       0.78      0.69      0.73      1805
#            1       0.70      0.70      0.70      1775
#            2       0.88      0.87      0.87       559
#            3       0.85      0.78      0.82      1030
#            4       0.82      0.87      0.84      1560
#            5       0.80      0.84      0.82      1644
#            6       0.79      0.94      0.86      1728
#            7       0.61      0.31      0.41       274
#            8       0.60      0.63      0.62       273
#            9       0.75      0.82      0.78       677
#           10       0.89      0.81      0.85      2186
#           11       0.90      0.90      0.90      1642
#           12       0.68      0.45      0.54       465
#           13       0.69      0.48      0.57       349
#           14       0.84      0.83      0.84       113
#           15       0.44      0.54      0.49       818
#           16       0.57      0.31      0.41       235
#           17       0.67      0.70      0.68       486
#           18       0.66      0.74      0.70       329
#           19       0.71      0.56      0.63       256
#           20       0.84      0.90      0.87      1445
#           21       0.75      0.79      0.77      1191
#           22       0.73      0.74      0.74      2744
#
#     accuracy                           0.77     23584
#    macro avg       0.74      0.70      0.71     23584
# weighted avg       0.77      0.77      0.77     23584
#
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 300, 300)          43855200
# _________________________________________________________________
# Conv1D_layer (Conv1D)        (None, 296, 128)          192128
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 128)               0
# _________________________________________________________________
# dense_layer (Dense)          (None, 23)                2967
# =================================================================
# Total params: 44,050,295
# Trainable params: 195,095
# Non-trainable params: 43,855,200
# _________________________________________________________________
# None
# Epoch 1/10
# 737/737 [==============================] - 34s 45ms/step - loss: 1.8106 - accuracy: 0.5205
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.9500 - accuracy: 0.7359
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.7502 - accuracy: 0.7870
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.6144 - accuracy: 0.8259
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.5274 - accuracy: 0.8498
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 6/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.4491 - accuracy: 0.8726
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 7/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.4009 - accuracy: 0.8841
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 8/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.3550 - accuracy: 0.8972
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 9/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.3160 - accuracy: 0.9072
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 10/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.2814 - accuracy: 0.9165
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 185/185 [==============================] - 5s 27ms/step - loss: 0.8002 - accuracy: 0.7781
#               precision    recall  f1-score   support
#
#            0       0.75      0.71      0.73      1805
#            1       0.68      0.76      0.72      1775
#            2       0.88      0.84      0.86       559
#            3       0.79      0.85      0.82      1030
#            4       0.82      0.86      0.84      1560
#            5       0.94      0.77      0.85      1644
#            6       0.73      0.95      0.83      1728
#            7       0.63      0.53      0.58       274
#            8       0.60      0.68      0.64       273
#            9       0.75      0.83      0.79       677
#           10       0.85      0.83      0.84      2186
#           11       0.91      0.91      0.91      1642
#           12       0.73      0.56      0.63       464
#           13       0.79      0.45      0.57       350
#           14       0.87      0.70      0.77       112
#           15       0.51      0.52      0.51       819
#           16       0.56      0.55      0.56       235
#           17       0.69      0.64      0.66       486
#           18       0.63      0.72      0.67       328
#           19       0.53      0.66      0.59       256
#           20       0.86      0.87      0.86      1445
#           21       0.84      0.77      0.80      1190
#           22       0.79      0.71      0.75      2745
#
#     accuracy                           0.78     23583
#    macro avg       0.74      0.73      0.73     23583
# weighted avg       0.78      0.78      0.78     23583
#
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 300, 300)          43354500
# _________________________________________________________________
# Conv1D_layer (Conv1D)        (None, 296, 128)          192128
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 128)               0
# _________________________________________________________________
# dense_layer (Dense)          (None, 23)                2967
# =================================================================
# Total params: 43,549,595
# Trainable params: 195,095
# Non-trainable params: 43,354,500
# _________________________________________________________________
# None
# Epoch 1/10
# 737/737 [==============================] - 34s 46ms/step - loss: 1.8006 - accuracy: 0.5229
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.9366 - accuracy: 0.7399
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/10
# 737/737 [==============================] - 34s 45ms/step - loss: 0.7445 - accuracy: 0.7900
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/10
# 737/737 [==============================] - 33s 45ms/step - loss: 0.6172 - accuracy: 0.8244
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.5244 - accuracy: 0.8497
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 6/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.4553 - accuracy: 0.8683
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 7/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.4008 - accuracy: 0.8830
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 8/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.3563 - accuracy: 0.8974
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 9/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.3246 - accuracy: 0.9046
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 10/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.2892 - accuracy: 0.9151
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 185/185 [==============================] - 5s 28ms/step - loss: 0.8178 - accuracy: 0.7658
#               precision    recall  f1-score   support
#
#            0       0.73      0.69      0.71      1806
#            1       0.69      0.71      0.70      1775
#            2       0.91      0.82      0.86       559
#            3       0.82      0.78      0.80      1030
#            4       0.82      0.87      0.85      1560
#            5       0.85      0.82      0.84      1644
#            6       0.79      0.91      0.85      1728
#            7       0.58      0.41      0.48       275
#            8       0.73      0.50      0.59       273
#            9       0.69      0.86      0.76       677
#           10       0.87      0.78      0.82      2186
#           11       0.86      0.92      0.89      1642
#           12       0.70      0.44      0.54       464
#           13       0.69      0.56      0.62       349
#           14       0.88      0.78      0.83       113
#           15       0.44      0.49      0.47       819
#           16       0.53      0.50      0.51       234
#           17       0.79      0.64      0.71       485
#           18       0.72      0.65      0.68       329
#           19       0.70      0.62      0.66       256
#           20       0.88      0.85      0.87      1445
#           21       0.83      0.75      0.79      1190
#           22       0.67      0.77      0.72      2744
#
#     accuracy                           0.77     23583
#    macro avg       0.75      0.70      0.72     23583
# weighted avg       0.77      0.77      0.76     23583
#
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300)]             0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 300, 300)          42951900
# _________________________________________________________________
# Conv1D_layer (Conv1D)        (None, 296, 128)          192128
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 128)               0
# _________________________________________________________________
# dense_layer (Dense)          (None, 23)                2967
# =================================================================
# Total params: 43,146,995
# Trainable params: 195,095
# Non-trainable params: 42,951,900
# _________________________________________________________________
# None
# Epoch 1/10
# 737/737 [==============================] - 35s 46ms/step - loss: 1.8114 - accuracy: 0.5141
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.9250 - accuracy: 0.7351
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.7356 - accuracy: 0.7882
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.6077 - accuracy: 0.8234
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.5167 - accuracy: 0.8499
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 6/10
# 737/737 [==============================] - 34s 47ms/step - loss: 0.4573 - accuracy: 0.8669
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 7/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.3907 - accuracy: 0.8852
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 8/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.3554 - accuracy: 0.8951
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 9/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.3112 - accuracy: 0.9079
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 10/10
# 737/737 [==============================] - 34s 46ms/step - loss: 0.2857 - accuracy: 0.9132
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 185/185 [==============================] - 5s 27ms/step - loss: 0.9083 - accuracy: 0.7430
#               precision    recall  f1-score   support
#
#            0       0.77      0.68      0.72      1806
#            1       0.74      0.68      0.71      1775
#            2       0.84      0.88      0.86       559
#            3       0.78      0.90      0.84      1029
#            4       0.92      0.83      0.87      1560
#            5       0.94      0.81      0.87      1644
#            6       0.82      0.94      0.87      1728
#            7       0.52      0.60      0.56       275
#            8       0.64      0.52      0.57       272
#            9       0.87      0.75      0.81       677
#           10       0.78      0.48      0.59      2187
#           11       0.84      0.94      0.89      1641
#           12       0.73      0.56      0.64       464
#           13       0.54      0.61      0.57       349
#           14       0.93      0.74      0.83       113
#           15       0.52      0.45      0.48       819
#           16       0.58      0.49      0.53       235
#           17       0.62      0.71      0.66       486
#           18       0.72      0.60      0.65       329
#           19       0.57      0.67      0.62       257
#           20       0.85      0.90      0.88      1444
#           21       0.67      0.81      0.73      1190
#           22       0.54      0.72      0.62      2744
#
#     accuracy                           0.74     23583
#    macro avg       0.73      0.71      0.71     23583
# weighted avg       0.75      0.74      0.74     23583
